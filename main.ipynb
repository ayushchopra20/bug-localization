# %% [markdown]
# ## Import Libraries

# %%
import os
import re
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\achop\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\achop\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Preprocessing (stopwords + stemming)

# %%
stop_words = set(stopwords.words("english"))
stemmer = PorterStemmer()

def preprocess_text(text: str) -> str:
    if not isinstance(text, str):
        return ""
    # lowercase
    text = text.lower()
    # keep letters/digits/underscores + spaces
    text = re.sub(r"[^a-z0-9_]+", " ", text)
    tokens = word_tokenize(text)
    tokens = [
        stemmer.stem(t)
        for t in tokens
        if t not in stop_words and len(t) > 1
    ]
    return " ".join(tokens)

# %% [markdown]
# ### Load AspectJ_Dataset dataset

# %%
bug_file = "CIS580_Assignment_BugLocalization\\AspectJ_Dataset.txt"   # path relative to your notebook

bugs_df = pd.read_csv(bug_file, sep="\t", encoding="utf-8")
print(bugs_df.columns)      # just to verify
bugs_df.head()
# Out:
# Index(['id', 'bug_id', 'summary', 'description', 'report_time',
#        'report_timestamp', 'status', 'commit', 'commit_timestamp', 'files',
#        'Unnamed: 10'],
#       dtype='object')
#    id  bug_id                                            summary  \
# 0   1  423257  Bug 423257 LTW - java.lang.VerifyError: Bad re...
# 1   2  420210  Bug 420210 Support additional message insert k...
# 2   3  419279  Bug 419279 ajc option to change -Xlint level p...
# 3   4  415266     Bug 415266 LTW not working when JMX is enabled
# 4   5  418129  Bug 418129 Can't introduce annotation onto int...
#
#                                          description          report_time  \
# 0                                                NaN  2013-12-04 19:43:22
# 1  It would be good to be able to insert the encl...  2013-10-23 16:00:16
# 2  The -Xlintfile option is not a great fit for c...  2013-10-11 15:20:08
# 3  When I enable JMX remote management on a JVM a...  2013-08-16 17:51:29
# 4                                                NaN  2013-09-26 14:31:09
#
#    report_timestamp          status   commit  commit_timestamp  \
# 0        1386200000  resolved fixed  dd88d21        1386350000
# 1        1382560000  resolved fixed  9319e34        1382560000
# 2        1381520000  resolved fixed  b2cd5fa        1382560000
# 3        1376690000  resolved fixed  9e992d6        1380650000
# 4        1380220000  resolved fixed  2393bef        1380650000
#
#                                                files  \
# 0  org.aspectj.ajdt.core/src/org/aspectj/ajdt/int...
# 1  org.aspectj.matcher/src/org/aspectj/weaver/Che...
# 2  org.aspectj.ajdt.core/src/org/aspectj/ajdt/int...
# 3   loadtime/src/org/aspectj/weaver/loadtime/Aj.java
# 4  tests/bugs174/pr418129/Target.java tests/bugs1...
#
#                                          Unnamed: 10
# 0  52:tests/src/org/aspectj/systemtest/incrementa...
# 1  63:org.aspectj.matcher/src/org/aspectj/weaver/...
# 2  6:org.aspectj.ajdt.core/src/org/aspectj/ajdt/i...
# 3  5:loadtime/src/org/aspectj/weaver/loadtime/Aj....
# 4  21:weaver/src/org/aspectj/weaver/bcel/BcelClas...

# %% [markdown]
# ### Combine text field and preprocess

# %%
import nltk
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\achop\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
bugs_df["text"] = (
    bugs_df["summary"].fillna("") + " " +
    bugs_df["description"].fillna("")
)

bugs_df["clean_text"] = bugs_df["text"].apply(preprocess_text)

len(bugs_df)
# Out:
# 593

# %% [markdown]
# ## Preprocess source files

# %%
source_root = "CIS580_Assignment_BugLocalization\\sourceFile_aspectj\\org.aspectj"

file_paths = []
file_texts = []

for root, _, files in os.walk(source_root):
    for fname in files:
        if not fname.endswith(".java"):
            continue
        full_path = os.path.join(root, fname)
        try:
            with open(full_path, "r", encoding="utf-8", errors="ignore") as f:
                raw = f.read()
        except Exception as e:
            print("Skipping file due to error:", full_path, e)
            continue

        file_paths.append(full_path)
        file_texts.append(preprocess_text(raw))

print("Total source files:", len(file_paths))
# Out:
# Total source files: 2394

# %% [markdown]
# ## Build TF-IDF Vector on all bug text and source text

# %%
all_docs = list(bugs_df["clean_text"]) + file_texts

vectorizer = TfidfVectorizer(
    max_df=0.9,      # ignore extremely common tokens
    min_df=2,        # ignore extremely rare tokens
    sublinear_tf=True
)

tfidf_matrix = vectorizer.fit_transform(all_docs)

n_bugs = len(bugs_df)
bug_matrix  = tfidf_matrix[:n_bugs, :]
file_matrix = tfidf_matrix[n_bugs:, :]

bug_matrix.shape, file_matrix.shape
# Out:
# ((593, 18850), (2394, 18850))

# %% [markdown]
# ## Compute Cosine Similarity based on TF-IDF vectors

# %%
index_to_file = {idx: path for idx, path in enumerate(file_paths)}
bug_rankings = {}   # bug_id -> {file_path: rank}
for bug_idx, row in bugs_df.iterrows():
    print(f"Processing bug {bug_idx+1}/{len(bugs_df)}")
    bug_id = row["bug_id"]

    bug_vec = bug_matrix[bug_idx]              # (1, vocab)
    sims = cosine_similarity(bug_vec, file_matrix)[0]   # 1D array

    sorted_idx = np.argsort(-sims)             # high → low

    ranking_dict = {}
    for rank, file_idx in enumerate(sorted_idx, start=1):
        ranking_dict[index_to_file[file_idx]] = rank

    bug_rankings[bug_id] = ranking_dict
# Out:
# Processing bug 1/593
# Processing bug 2/593
# Processing bug 3/593
# Processing bug 4/593
# Processing bug 5/593
# Processing bug 6/593
# Processing bug 7/593
# Processing bug 8/593
# Processing bug 9/593
# Processing bug 10/593
# Processing bug 11/593
# Processing bug 12/593
# Processing bug 13/593
# Processing bug 14/593
# Processing bug 15/593
# Processing bug 16/593
# Processing bug 17/593
# Processing bug 18/593
# Processing bug 19/593
# Processing bug 20/593
# Processing bug 21/593
# Processing bug 22/593
# Processing bug 23/593
# Processing bug 24/593
# Processing bug 25/593
# Processing bug 26/593
# Processing bug 27/593
# Processing bug 28/593
# Processing bug 29/593
# Processing bug 30/593
# Processing bug 31/593
# Processing bug 32/593
# Processing bug 33/593
# Processing bug 34/593
# Processing bug 35/593
# Processing bug 36/593
# Processing bug 37/593
# Processing bug 38/593
# Processing bug 39/593
# Processing bug 40/593
# Processing bug 41/593
# Processing bug 42/593
# Processing bug 43/593
# Processing bug 44/593
# Processing bug 45/593
# Processing bug 46/593
# Processing bug 47/593
# Processing bug 48/593
# Processing bug 49/593
# Processing bug 50/593
# Processing bug 51/593
# Processing bug 52/593
# Processing bug 53/593
# Processing bug 54/593
# Processing bug 55/593
# Processing bug 56/593
# Processing bug 57/593
# Processing bug 58/593
# Processing bug 59/593
# Processing bug 60/593
# Processing bug 61/593
# Processing bug 62/593
# Processing bug 63/593
# Processing bug 64/593
# Processing bug 65/593
# Processing bug 66/593
# Processing bug 67/593
# Processing bug 68/593
# Processing bug 69/593
# Processing bug 70/593
# Processing bug 71/593
# Processing bug 72/593
# Processing bug 73/593
# Processing bug 74/593
# Processing bug 75/593
# Processing bug 76/593
# Processing bug 77/593
# Processing bug 78/593
# Processing bug 79/593
# Processing bug 80/593
# Processing bug 81/593
# Processing bug 82/593
# Processing bug 83/593
# Processing bug 84/593
# Processing bug 85/593
# Processing bug 86/593
# Processing bug 87/593
# Processing bug 88/593
# Processing bug 89/593
# Processing bug 90/593
# Processing bug 91/593
# Processing bug 92/593
# Processing bug 93/593
# Processing bug 94/593
# Processing bug 95/593
# Processing bug 96/593
# Processing bug 97/593
# Processing bug 98/593
# Processing bug 99/593
# Processing bug 100/593
# Processing bug 101/593
# Processing bug 102/593
# Processing bug 103/593
# Processing bug 104/593
# Processing bug 105/593
# Processing bug 106/593
# Processing bug 107/593
# Processing bug 108/593
# Processing bug 109/593
# Processing bug 110/593
# Processing bug 111/593
# Processing bug 112/593
# Processing bug 113/593
# Processing bug 114/593
# Processing bug 115/593
# Processing bug 116/593
# Processing bug 117/593
# Processing bug 118/593
# Processing bug 119/593
# Processing bug 120/593
# Processing bug 121/593
# Processing bug 122/593
# Processing bug 123/593
# Processing bug 124/593
# Processing bug 125/593
# Processing bug 126/593
# Processing bug 127/593
# Processing bug 128/593
# Processing bug 129/593
# Processing bug 130/593
# Processing bug 131/593
# Processing bug 132/593
# Processing bug 133/593
# Processing bug 134/593
# Processing bug 135/593
# Processing bug 136/593
# Processing bug 137/593
# Processing bug 138/593
# Processing bug 139/593
# Processing bug 140/593
# Processing bug 141/593
# Processing bug 142/593
# Processing bug 143/593
# Processing bug 144/593
# Processing bug 145/593
# Processing bug 146/593
# Processing bug 147/593
# Processing bug 148/593
# Processing bug 149/593
# Processing bug 150/593
# Processing bug 151/593
# Processing bug 152/593
# Processing bug 153/593
# Processing bug 154/593
# Processing bug 155/593
# Processing bug 156/593
# Processing bug 157/593
# Processing bug 158/593
# Processing bug 159/593
# Processing bug 160/593
# Processing bug 161/593
# Processing bug 162/593
# Processing bug 163/593
# Processing bug 164/593
# Processing bug 165/593
# Processing bug 166/593
# Processing bug 167/593
# Processing bug 168/593
# Processing bug 169/593
# Processing bug 170/593
# Processing bug 171/593
# Processing bug 172/593
# Processing bug 173/593
# Processing bug 174/593
# Processing bug 175/593
# Processing bug 176/593
# Processing bug 177/593
# Processing bug 178/593
# Processing bug 179/593
# Processing bug 180/593
# Processing bug 181/593
# Processing bug 182/593
# Processing bug 183/593
# Processing bug 184/593
# Processing bug 185/593
# Processing bug 186/593
# Processing bug 187/593
# Processing bug 188/593
# Processing bug 189/593
# Processing bug 190/593
# Processing bug 191/593
# Processing bug 192/593
# Processing bug 193/593
# Processing bug 194/593
# Processing bug 195/593
# Processing bug 196/593
# Processing bug 197/593
# Processing bug 198/593
# Processing bug 199/593
# Processing bug 200/593
# Processing bug 201/593
# Processing bug 202/593
# Processing bug 203/593
# Processing bug 204/593
# Processing bug 205/593
# Processing bug 206/593
# Processing bug 207/593
# Processing bug 208/593
# Processing bug 209/593
# Processing bug 210/593
# Processing bug 211/593
# Processing bug 212/593
# Processing bug 213/593
# Processing bug 214/593
# Processing bug 215/593
# Processing bug 216/593
# Processing bug 217/593
# Processing bug 218/593
# Processing bug 219/593
# Processing bug 220/593
# Processing bug 221/593
# Processing bug 222/593
# Processing bug 223/593
# Processing bug 224/593
# Processing bug 225/593
# Processing bug 226/593
# Processing bug 227/593
# Processing bug 228/593
# Processing bug 229/593
# Processing bug 230/593
# Processing bug 231/593
# Processing bug 232/593
# Processing bug 233/593
# Processing bug 234/593
# Processing bug 235/593
# Processing bug 236/593
# Processing bug 237/593
# Processing bug 238/593
# Processing bug 239/593
# Processing bug 240/593
# Processing bug 241/593
# Processing bug 242/593
# Processing bug 243/593
# Processing bug 244/593
# Processing bug 245/593
# Processing bug 246/593
# Processing bug 247/593
# Processing bug 248/593
# Processing bug 249/593
# Processing bug 250/593
# Processing bug 251/593
# Processing bug 252/593
# Processing bug 253/593
# Processing bug 254/593
# Processing bug 255/593
# Processing bug 256/593
# Processing bug 257/593
# Processing bug 258/593
# Processing bug 259/593
# Processing bug 260/593
# Processing bug 261/593
# Processing bug 262/593
# Processing bug 263/593
# Processing bug 264/593
# Processing bug 265/593
# Processing bug 266/593
# Processing bug 267/593
# Processing bug 268/593
# Processing bug 269/593
# Processing bug 270/593
# Processing bug 271/593
# Processing bug 272/593
# Processing bug 273/593
# Processing bug 274/593
# Processing bug 275/593
# Processing bug 276/593
# Processing bug 277/593
# Processing bug 278/593
# Processing bug 279/593
# Processing bug 280/593
# Processing bug 281/593
# Processing bug 282/593
# Processing bug 283/593
# Processing bug 284/593
# Processing bug 285/593
# Processing bug 286/593
# Processing bug 287/593
# Processing bug 288/593
# Processing bug 289/593
# Processing bug 290/593
# Processing bug 291/593
# Processing bug 292/593
# Processing bug 293/593
# Processing bug 294/593
# Processing bug 295/593
# Processing bug 296/593
# Processing bug 297/593
# Processing bug 298/593
# Processing bug 299/593
# Processing bug 300/593
# Processing bug 301/593
# Processing bug 302/593
# Processing bug 303/593
# Processing bug 304/593
# Processing bug 305/593
# Processing bug 306/593
# Processing bug 307/593
# Processing bug 308/593
# Processing bug 309/593
# Processing bug 310/593
# Processing bug 311/593
# Processing bug 312/593
# Processing bug 313/593
# Processing bug 314/593
# Processing bug 315/593
# Processing bug 316/593
# Processing bug 317/593
# Processing bug 318/593
# Processing bug 319/593
# Processing bug 320/593
# Processing bug 321/593
# Processing bug 322/593
# Processing bug 323/593
# Processing bug 324/593
# Processing bug 325/593
# Processing bug 326/593
# Processing bug 327/593
# Processing bug 328/593
# Processing bug 329/593
# Processing bug 330/593
# Processing bug 331/593
# Processing bug 332/593
# Processing bug 333/593
# Processing bug 334/593
# Processing bug 335/593
# Processing bug 336/593
# Processing bug 337/593
# Processing bug 338/593
# Processing bug 339/593
# Processing bug 340/593
# Processing bug 341/593
# Processing bug 342/593
# Processing bug 343/593
# Processing bug 344/593
# Processing bug 345/593
# Processing bug 346/593
# Processing bug 347/593
# Processing bug 348/593
# Processing bug 349/593
# Processing bug 350/593
# Processing bug 351/593
# Processing bug 352/593
# Processing bug 353/593
# Processing bug 354/593
# Processing bug 355/593
# Processing bug 356/593
# Processing bug 357/593
# Processing bug 358/593
# Processing bug 359/593
# Processing bug 360/593
# Processing bug 361/593
# Processing bug 362/593
# Processing bug 363/593
# Processing bug 364/593
# Processing bug 365/593
# Processing bug 366/593
# Processing bug 367/593
# Processing bug 368/593
# Processing bug 369/593
# Processing bug 370/593
# Processing bug 371/593
# Processing bug 372/593
# Processing bug 373/593
# Processing bug 374/593
# Processing bug 375/593
# Processing bug 376/593
# Processing bug 377/593
# Processing bug 378/593
# Processing bug 379/593
# Processing bug 380/593
# Processing bug 381/593
# Processing bug 382/593
# Processing bug 383/593
# Processing bug 384/593
# Processing bug 385/593
# Processing bug 386/593
# Processing bug 387/593
# Processing bug 388/593
# Processing bug 389/593
# Processing bug 390/593
# Processing bug 391/593
# Processing bug 392/593
# Processing bug 393/593
# Processing bug 394/593
# Processing bug 395/593
# Processing bug 396/593
# Processing bug 397/593
# Processing bug 398/593
# Processing bug 399/593
# Processing bug 400/593
# Processing bug 401/593
# Processing bug 402/593
# Processing bug 403/593
# Processing bug 404/593
# Processing bug 405/593
# Processing bug 406/593
# Processing bug 407/593
# Processing bug 408/593
# Processing bug 409/593
# Processing bug 410/593
# Processing bug 411/593
# Processing bug 412/593
# Processing bug 413/593
# Processing bug 414/593
# Processing bug 415/593
# Processing bug 416/593
# Processing bug 417/593
# Processing bug 418/593
# Processing bug 419/593
# Processing bug 420/593
# Processing bug 421/593
# Processing bug 422/593
# Processing bug 423/593
# Processing bug 424/593
# Processing bug 425/593
# Processing bug 426/593
# Processing bug 427/593
# Processing bug 428/593
# Processing bug 429/593
# Processing bug 430/593
# Processing bug 431/593
# Processing bug 432/593
# Processing bug 433/593
# Processing bug 434/593
# Processing bug 435/593
# Processing bug 436/593
# Processing bug 437/593
# Processing bug 438/593
# Processing bug 439/593
# Processing bug 440/593
# Processing bug 441/593
# Processing bug 442/593
# Processing bug 443/593
# Processing bug 444/593
# Processing bug 445/593
# Processing bug 446/593
# Processing bug 447/593
# Processing bug 448/593
# Processing bug 449/593
# Processing bug 450/593
# Processing bug 451/593
# Processing bug 452/593
# Processing bug 453/593
# Processing bug 454/593
# Processing bug 455/593
# Processing bug 456/593
# Processing bug 457/593
# Processing bug 458/593
# Processing bug 459/593
# Processing bug 460/593
# Processing bug 461/593
# Processing bug 462/593
# Processing bug 463/593
# Processing bug 464/593
# Processing bug 465/593
# Processing bug 466/593
# Processing bug 467/593
# Processing bug 468/593
# Processing bug 469/593
# Processing bug 470/593
# Processing bug 471/593
# Processing bug 472/593
# Processing bug 473/593
# Processing bug 474/593
# Processing bug 475/593
# Processing bug 476/593
# Processing bug 477/593
# Processing bug 478/593
# Processing bug 479/593
# Processing bug 480/593
# Processing bug 481/593
# Processing bug 482/593
# Processing bug 483/593
# Processing bug 484/593
# Processing bug 485/593
# Processing bug 486/593
# Processing bug 487/593
# Processing bug 488/593
# Processing bug 489/593
# Processing bug 490/593
# Processing bug 491/593
# Processing bug 492/593
# Processing bug 493/593
# Processing bug 494/593
# Processing bug 495/593
# Processing bug 496/593
# Processing bug 497/593
# Processing bug 498/593
# Processing bug 499/593
# Processing bug 500/593
# Processing bug 501/593
# Processing bug 502/593
# Processing bug 503/593
# Processing bug 504/593
# Processing bug 505/593
# Processing bug 506/593
# Processing bug 507/593
# Processing bug 508/593
# Processing bug 509/593
# Processing bug 510/593
# Processing bug 511/593
# Processing bug 512/593
# Processing bug 513/593
# Processing bug 514/593
# Processing bug 515/593
# Processing bug 516/593
# Processing bug 517/593
# Processing bug 518/593
# Processing bug 519/593
# Processing bug 520/593
# Processing bug 521/593
# Processing bug 522/593
# Processing bug 523/593
# Processing bug 524/593
# Processing bug 525/593
# Processing bug 526/593
# Processing bug 527/593
# Processing bug 528/593
# Processing bug 529/593
# Processing bug 530/593
# Processing bug 531/593
# Processing bug 532/593
# Processing bug 533/593
# Processing bug 534/593
# Processing bug 535/593
# Processing bug 536/593
# Processing bug 537/593
# Processing bug 538/593
# Processing bug 539/593
# Processing bug 540/593
# Processing bug 541/593
# Processing bug 542/593
# Processing bug 543/593
# Processing bug 544/593
# Processing bug 545/593
# Processing bug 546/593
# Processing bug 547/593
# Processing bug 548/593
# Processing bug 549/593
# Processing bug 550/593
# Processing bug 551/593
# Processing bug 552/593
# Processing bug 553/593
# Processing bug 554/593
# Processing bug 555/593
# Processing bug 556/593
# Processing bug 557/593
# Processing bug 558/593
# Processing bug 559/593
# Processing bug 560/593
# Processing bug 561/593
# Processing bug 562/593
# Processing bug 563/593
# Processing bug 564/593
# Processing bug 565/593
# Processing bug 566/593
# Processing bug 567/593
# Processing bug 568/593
# Processing bug 569/593
# Processing bug 570/593
# Processing bug 571/593
# Processing bug 572/593
# Processing bug 573/593
# Processing bug 574/593
# Processing bug 575/593
# Processing bug 576/593
# Processing bug 577/593
# Processing bug 578/593
# Processing bug 579/593
# Processing bug 580/593
# Processing bug 581/593
# Processing bug 582/593
# Processing bug 583/593
# Processing bug 584/593
# Processing bug 585/593
# Processing bug 586/593
# Processing bug 587/593
# Processing bug 588/593
# Processing bug 589/593
# Processing bug 590/593
# Processing bug 591/593
# Processing bug 592/593
# Processing bug 593/593

# %%
rows_for_csv = []

normalized_paths = [p.replace("\\", "/") for p in file_paths]

for _, row in bugs_df.iterrows():
    bug_id = row["bug_id"]
    gt_raw = str(row["files"])

    gt_list = [g.strip() for g in gt_raw.split() if g.strip()]

    ranks_dict = bug_rankings[bug_id]
    best_rank = None

    for gt in gt_list:
        gt_norm = gt.replace("\\", "/")

        # Extract only the filename
        print("GT norm:", gt_norm)
        filename = gt_norm.split("/")[-1]  # e.g. AjState.java
        print("Filename to match:", filename)
        # Now match using filename only (because actual files are renamed)
        for file_path_norm, rank in ranks_dict.items():

            fp = file_path_norm.replace("\\", "/")

            # This is the CORRECT matching rule
            if filename in fp:
                if best_rank is None or rank < best_rank:
                    best_rank = rank

    if best_rank is None:
        best_rank = len(file_paths) + 1

    rows_for_csv.append({"BugID": bug_id, "Rank": best_rank})

result_df = pd.DataFrame(rows_for_csv)
result_df.to_csv("bug_localization_ranks.csv", index=False)
result_df.head()
# Out:
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjState.java
# Filename to match: AjState.java
# GT norm: tests/bugs175/pr423257/AspectX.java
# Filename to match: AspectX.java
# GT norm: tests/bugs175/pr423257/Test.java
# Filename to match: Test.java
# GT norm: tests/src/org/aspectj/systemtest/AllTests17.java
# Filename to match: AllTests17.java
# GT norm: tests/src/org/aspectj/systemtest/ajc175/Ajc175Tests.java
# Filename to match: Ajc175Tests.java
# GT norm: tests/src/org/aspectj/systemtest/ajc175/AllTestsAspectJ175.java
# Filename to match: AllTestsAspectJ175.java
# GT norm: tests/src/org/aspectj/systemtest/incremental/tools/MultiProjectIncrementalTests.java
# Filename to match: MultiProjectIncrementalTests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/asm/StackMapAdder.java
# Filename to match: StackMapAdder.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/Checker.java
# Filename to match: Checker.java
# GT norm: tests/bugs174/extra_inserts/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/ajc174/Ajc174Tests.java
# Filename to match: Ajc174Tests.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildConfig.java
# Filename to match: AjBuildConfig.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/Lint.java
# Filename to match: Lint.java
# GT norm: testing/newsrc/org/aspectj/testing/CompileSpec.java
# Filename to match: CompileSpec.java
# GT norm: tests/bugs174/pr419279/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/ajc174/Ajc174Tests.java
# Filename to match: Ajc174Tests.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/Aj.java
# Filename to match: Aj.java
# GT norm: tests/bugs174/pr418129/Target.java
# Filename to match: Target.java
# GT norm: tests/bugs174/pr418129/Target2.java
# Filename to match: Target2.java
# GT norm: tests/bugs174/pr418129/Target3.java
# Filename to match: Target3.java
# GT norm: tests/bugs174/pr418129/Target4.java
# Filename to match: Target4.java
# GT norm: tests/src/org/aspectj/systemtest/ajc174/Ajc174Tests.java
# Filename to match: Ajc174Tests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelClassWeaver.java
# Filename to match: BcelClassWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWorld.java
# Filename to match: BcelWorld.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/LazyMethodGen.java
# Filename to match: LazyMethodGen.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/Aj.java
# Filename to match: Aj.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/ClassLoaderWeavingAdaptor.java
# Filename to match: ClassLoaderWeavingAdaptor.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/Options.java
# Filename to match: Options.java
# GT norm: tests/bugs174/pr368046/Azpect.java
# Filename to match: Azpect.java
# GT norm: tests/bugs174/pr368046/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/ajc174/Ajc174Tests.java
# Filename to match: Ajc174Tests.java
# GT norm: tests/bugs174/pr413378/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/AllTests17.java
# Filename to match: AllTests17.java
# GT norm: tests/src/org/aspectj/systemtest/ajc174/Ajc174Tests.java
# Filename to match: Ajc174Tests.java
# GT norm: tests/src/org/aspectj/systemtest/ajc174/AllTestsAspectJ174.java
# Filename to match: AllTestsAspectJ174.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelTypeMunger.java
# Filename to match: BcelTypeMunger.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjState.java
# Filename to match: AjState.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ReferenceType.java
# Filename to match: ReferenceType.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWeaver.java
# Filename to match: BcelWeaver.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ResolvedType.java
# Filename to match: ResolvedType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/AjcMemberMaker.java
# Filename to match: AjcMemberMaker.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/WeaverMessages.java
# Filename to match: WeaverMessages.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/WildAnnotationTypePattern.java
# Filename to match: WildAnnotationTypePattern.java
# GT norm: tests/bugs172/pr391384/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/ajc172/Ajc172Tests.java
# Filename to match: Ajc172Tests.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/TypeVariable.java
# Filename to match: TypeVariable.java
# GT norm: tests/bugs172/pr394535/Bug.java
# Filename to match: Bug.java
# GT norm: tests/bugs172/pr394535/Bug2.java
# Filename to match: Bug2.java
# GT norm: tests/src/org/aspectj/systemtest/ajc172/Ajc172Tests.java
# Filename to match: Ajc172Tests.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/BoundedReferenceType.java
# Filename to match: BoundedReferenceType.java
# GT norm: tests/bugs172/pr399590/Cage.java
# Filename to match: Cage.java
# GT norm: tests/bugs172/pr399590/Cage2.java
# Filename to match: Cage2.java
# GT norm: tests/bugs172/pr399590/five/Cage.java
# Filename to match: Cage.java
# GT norm: tests/bugs172/pr399590/five/Cage2.java
# Filename to match: Cage2.java
# GT norm: tests/bugs172/pr399590/four/Cage.java
# Filename to match: Cage.java
# GT norm: tests/bugs172/pr399590/four/Cage2.java
# Filename to match: Cage2.java
# GT norm: tests/bugs172/pr399590/three/Cage.java
# Filename to match: Cage.java
# GT norm: tests/bugs172/pr399590/three/Cage2.java
# Filename to match: Cage2.java
# GT norm: tests/bugs172/pr399590/two/Cage.java
# Filename to match: Cage.java
# GT norm: tests/bugs172/pr399590/two/Cage2.java
# Filename to match: Cage2.java
# GT norm: tests/src/org/aspectj/systemtest/ajc172/Ajc172Tests.java
# Filename to match: Ajc172Tests.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseSourceType.java
# Filename to match: EclipseSourceType.java
# GT norm: tests/bugs172/pr398588/Anno.java
# Filename to match: Anno.java
# GT norm: tests/bugs172/pr398588/Anno2.java
# Filename to match: Anno2.java
# GT norm: tests/bugs172/pr398588/AspectA.java
# Filename to match: AspectA.java
# GT norm: tests/bugs172/pr398588/AspectB.java
# Filename to match: AspectB.java
# GT norm: tests/bugs172/pr398588/AspectC.java
# Filename to match: AspectC.java
# GT norm: tests/bugs172/pr398588/AspectD.java
# Filename to match: AspectD.java
# GT norm: tests/bugs172/pr398588/Blah.java
# Filename to match: Blah.java
# GT norm: tests/bugs172/pr398588/Code.java
# Filename to match: Code.java
# GT norm: tests/bugs172/pr398588/Code2.java
# Filename to match: Code2.java
# GT norm: tests/src/org/aspectj/systemtest/ajc172/Ajc172Tests.java
# Filename to match: Ajc172Tests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWorld.java
# Filename to match: BcelWorld.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/AndPointcut.java
# Filename to match: AndPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/asm/StackMapAdder.java
# Filename to match: StackMapAdder.java
# GT norm: build/src/org/aspectj/internal/tools/ant/taskdefs/Checklics.java
# Filename to match: Checklics.java
# GT norm: util/src/org/aspectj/util/LangUtil.java
# Filename to match: LangUtil.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/AbstractIndexedFileCacheBacking.java
# Filename to match: AbstractIndexedFileCacheBacking.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/AsynchronousFileCacheBacking.java
# Filename to match: AsynchronousFileCacheBacking.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/DefaultFileCacheBacking.java
# Filename to match: DefaultFileCacheBacking.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/FlatFileCacheBacking.java
# Filename to match: FlatFileCacheBacking.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/ZippedFileCacheBacking.java
# Filename to match: ZippedFileCacheBacking.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/AbstractCacheBackingTestSupport.java
# Filename to match: AbstractCacheBackingTestSupport.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/AsynchronousFileCacheBackingTestSupport.java
# Filename to match: AsynchronousFileCacheBackingTestSupport.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/CacheTests.java
# Filename to match: CacheTests.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/DefaultCacheKeyResolverTest.java
# Filename to match: DefaultCacheKeyResolverTest.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/DefaultFileCacheBackingTest.java
# Filename to match: DefaultFileCacheBackingTest.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/FlatFileCacheBackingTest.java
# Filename to match: FlatFileCacheBackingTest.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/SimpleClassCacheTest.java
# Filename to match: SimpleClassCacheTest.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/WeavedClassCacheTest.java
# Filename to match: WeavedClassCacheTest.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/ZippedFileCacheBackingTest.java
# Filename to match: ZippedFileCacheBackingTest.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/ClassLoaderWeavingAdaptor.java
# Filename to match: ClassLoaderWeavingAdaptor.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/WeavingURLClassLoader.java
# Filename to match: WeavingURLClassLoader.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/tools/GeneratedClassHandler.java
# Filename to match: GeneratedClassHandler.java
# GT norm: util/src/org/aspectj/util/LangUtil.java
# Filename to match: LangUtil.java
# GT norm: weaver/src/org/aspectj/weaver/tools/WeavingAdaptor.java
# Filename to match: WeavingAdaptor.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/CacheBacking.java
# Filename to match: CacheBacking.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/CacheStatistics.java
# Filename to match: CacheStatistics.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/CachedClassEntry.java
# Filename to match: CachedClassEntry.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/CachedClassReference.java
# Filename to match: CachedClassReference.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/DefaultCacheFactory.java
# Filename to match: DefaultCacheFactory.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/DefaultCacheKeyResolver.java
# Filename to match: DefaultCacheKeyResolver.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/DefaultFileCacheBacking.java
# Filename to match: DefaultFileCacheBacking.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/GeneratedCachedClassHandler.java
# Filename to match: GeneratedCachedClassHandler.java
# GT norm: weaver/src/org/aspectj/weaver/tools/cache/WeavedClassCache.java
# Filename to match: WeavedClassCache.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/DefaultFileCacheBackingTest.java
# Filename to match: DefaultFileCacheBackingTest.java
# GT norm: weaver/testsrc/org/aspectj/weaver/tools/cache/WeavedClassCacheTest.java
# Filename to match: WeavedClassCacheTest.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseTypeMunger.java
# Filename to match: EclipseTypeMunger.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/EnumAnnotationValue.java
# Filename to match: EnumAnnotationValue.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/StandardAnnotation.java
# Filename to match: StandardAnnotation.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/WildAnnotationTypePattern.java
# Filename to match: WildAnnotationTypePattern.java
# GT norm: tests/bugs172/pr389752/Code.java
# Filename to match: Code.java
# GT norm: tests/bugs172/pr389752/Code2.java
# Filename to match: Code2.java
# GT norm: tests/bugs172/pr389752/Code3.java
# Filename to match: Code3.java
# GT norm: tests/src/org/aspectj/systemtest/ajc172/Ajc172Tests.java
# Filename to match: Ajc172Tests.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/AstUtil.java
# Filename to match: AstUtil.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/InterTypeMethodDeclaration.java
# Filename to match: InterTypeMethodDeclaration.java
# GT norm: tests/bugs172/pr389750/Clazz.java
# Filename to match: Clazz.java
# GT norm: tests/bugs172/pr389750/Clazz2.java
# Filename to match: Clazz2.java
# GT norm: tests/bugs172/pr389750/Clazz3.java
# Filename to match: Clazz3.java
# GT norm: tests/bugs172/pr389750/Clazz4.java
# Filename to match: Clazz4.java
# GT norm: tests/src/org/aspectj/systemtest/AllTests17.java
# Filename to match: AllTests17.java
# GT norm: tests/src/org/aspectj/systemtest/ajc172/Ajc172Tests.java
# Filename to match: Ajc172Tests.java
# GT norm: tests/src/org/aspectj/systemtest/ajc172/AllTestsAspectJ172.java
# Filename to match: AllTestsAspectJ172.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/LazyMethodGen.java
# Filename to match: LazyMethodGen.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/ValidateAtAspectJAnnotationsVisitor.java
# Filename to match: ValidateAtAspectJAnnotationsVisitor.java
# GT norm: tests/bugs171/pr384401/X.java
# Filename to match: X.java
# GT norm: tests/src/org/aspectj/systemtest/ajc171/Ajc171Tests.java
# Filename to match: Ajc171Tests.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/problem/AjProblemReporter.java
# Filename to match: AjProblemReporter.java
# GT norm: tests/bugs171/pr387444/Code.java
# Filename to match: Code.java
# GT norm: tests/bugs171/pr387444/Code2.java
# Filename to match: Code2.java
# GT norm: tests/src/org/aspectj/systemtest/ajc171/Ajc171Tests.java
# Filename to match: Ajc171Tests.java
# GT norm: tests/src/org/aspectj/systemtest/ajc171/Ajc171Tests_need17jre.java
# Filename to match: Ajc171Tests_need17jre.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/problem/AjProblemReporter.java
# Filename to match: AjProblemReporter.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ResolvedType.java
# Filename to match: ResolvedType.java
# GT norm: tests/bugs171/pr386049/de/scrum_master/galileo/filter/BasicFilter.java
# Filename to match: BasicFilter.java
# GT norm: tests/bugs171/pr386049/de/scrum_master/galileo/filter/JsoupFilter.java
# Filename to match: JsoupFilter.java
# GT norm: tests/bugs171/pr387568/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/ajc171/Ajc171Tests.java
# Filename to match: Ajc171Tests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelTypeMunger.java
# Filename to match: BcelTypeMunger.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseFactory.java
# Filename to match: EclipseFactory.java
# GT norm: tests/bugs171/pr384398/A.java
# Filename to match: A.java
# GT norm: tests/bugs171/pr384398/B.java
# Filename to match: B.java
# GT norm: tests/bugs171/pr384398_2/A.java
# Filename to match: A.java
# GT norm: tests/bugs171/pr384398_2/B.java
# Filename to match: B.java
# GT norm: tests/src/org/aspectj/systemtest/AllTests17.java
# Filename to match: AllTests17.java
# GT norm: tests/src/org/aspectj/systemtest/ajc171/Ajc171Tests.java
# Filename to match: Ajc171Tests.java
# GT norm: tests/src/org/aspectj/systemtest/ajc171/AllTestsAspectJ171.java
# Filename to match: AllTestsAspectJ171.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/Dump.java
# Filename to match: Dump.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ResolvedType.java
# Filename to match: ResolvedType.java
# GT norm: tests/bugs170/pr382189/covbug/A.java
# Filename to match: A.java
# GT norm: tests/bugs170/pr382189/covbug/B.java
# Filename to match: B.java
# GT norm: tests/bugs170/pr382189/covbug/SuperA.java
# Filename to match: SuperA.java
# GT norm: tests/bugs170/pr382189/covbug/SuperB.java
# Filename to match: SuperB.java
# GT norm: tests/bugs170/pr382189/covbug/cc/covbug/A.java
# Filename to match: A.java
# GT norm: tests/bugs170/pr382189/covbug/cc/covbug/B.java
# Filename to match: B.java
# GT norm: tests/bugs170/pr382189/covbug/cc/covbug/SuperA.java
# Filename to match: SuperA.java
# GT norm: tests/bugs170/pr382189/covbug/cc/covbug/SuperB.java
# Filename to match: SuperB.java
# GT norm: tests/bugs170/pr382189/covbug/pj/Foo.java
# Filename to match: Foo.java
# GT norm: tests/bugs170/pr382189/one/A.java
# Filename to match: A.java
# GT norm: tests/bugs170/pr382189/one/B.java
# Filename to match: B.java
# GT norm: tests/bugs170/pr382189/one/SuperA.java
# Filename to match: SuperA.java
# GT norm: tests/bugs170/pr382189/one/SuperB.java
# Filename to match: SuperB.java
# GT norm: tests/bugs170/pr382189/three/A.java
# Filename to match: A.java
# GT norm: tests/bugs170/pr382189/three/B.java
# Filename to match: B.java
# GT norm: tests/bugs170/pr382189/three/SuperA.java
# Filename to match: SuperA.java
# GT norm: tests/bugs170/pr382189/three/SuperB.java
# Filename to match: SuperB.java
# GT norm: tests/bugs170/pr382189/two/A.java
# Filename to match: A.java
# GT norm: tests/bugs170/pr382189/two/B.java
# Filename to match: B.java
# GT norm: tests/bugs170/pr382189/two/SuperA.java
# Filename to match: SuperA.java
# GT norm: tests/bugs170/pr382189/two/SuperB.java
# Filename to match: SuperB.java
# GT norm: tests/bugs170/pr382435/one/bug/A.java
# Filename to match: A.java
# GT norm: tests/bugs170/pr382435/two/bug/A.java
# Filename to match: A.java
# GT norm: tests/src/org/aspectj/systemtest/ajc170/Ajc170Tests.java
# Filename to match: Ajc170Tests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelTypeMunger.java
# Filename to match: BcelTypeMunger.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/AccessForInlineVisitor.java
# Filename to match: AccessForInlineVisitor.java
# GT norm: tests/bugs170/pr382723/Foo.java
# Filename to match: Foo.java
# GT norm: tests/bugs170/pr382723/FooAspect.java
# Filename to match: FooAspect.java
# GT norm: tests/bugs170/pr382723/FooAspect2.java
# Filename to match: FooAspect2.java
# GT norm: tests/bugs170/pr382723/FooAspect3.java
# Filename to match: FooAspect3.java
# GT norm: tests/src/org/aspectj/systemtest/ajc170/Ajc170Tests.java
# Filename to match: Ajc170Tests.java
# GT norm: taskdefs/src/org/aspectj/tools/ant/taskdefs/AjcTask.java
# Filename to match: AjcTask.java
# GT norm: tests/bugs170/pr376351/R.java
# Filename to match: R.java
# GT norm: tests/bugs170/pr376351/R1.java
# Filename to match: R1.java
# GT norm: tests/bugs170/pr376351/RAj.java
# Filename to match: RAj.java
# GT norm: tests/src/org/aspectj/systemtest/ajc170/Ajc170Tests.java
# Filename to match: Ajc170Tests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/asm/StackMapAdder.java
# Filename to match: StackMapAdder.java
# GT norm: tests/bugs170/pr376139/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/ajc170/Ajc170Tests.java
# Filename to match: Ajc170Tests.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/PointcutEvaluationExpenseComparator.java
# Filename to match: PointcutEvaluationExpenseComparator.java
# GT norm: tests/src/org/aspectj/systemtest/ajc170/Ajc170Tests.java
# Filename to match: Ajc170Tests.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseFactory.java
# Filename to match: EclipseFactory.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ReferenceType.java
# Filename to match: ReferenceType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ResolvedType.java
# Filename to match: ResolvedType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/TypeFactory.java
# Filename to match: TypeFactory.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/TypeVariableReferenceType.java
# Filename to match: TypeVariableReferenceType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/UnresolvedType.java
# Filename to match: UnresolvedType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/UnresolvedTypeVariableReferenceType.java
# Filename to match: UnresolvedTypeVariableReferenceType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/World.java
# Filename to match: World.java
# GT norm: bridge/src/org/aspectj/bridge/context/CompilationAndWeavingContext.java
# Filename to match: CompilationAndWeavingContext.java
# GT norm: tests/bugs170/pr371998/AspectTest.java
# Filename to match: AspectTest.java
# GT norm: tests/src/org/aspectj/systemtest/ajc170/Ajc170Tests.java
# Filename to match: Ajc170Tests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/AtAjAttributes.java
# Filename to match: AtAjAttributes.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/TypeFactory.java
# Filename to match: TypeFactory.java
# GT norm: tests/src/org/aspectj/systemtest/ajc170/Ajc170Tests.java
# Filename to match: Ajc170Tests.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ReferenceType.java
# Filename to match: ReferenceType.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: weaver/src/org/aspectj/weaver/loadtime/definition/DocumentParser.java
# Filename to match: DocumentParser.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ShadowMunger.java
# Filename to match: ShadowMunger.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelClassWeaver.java
# Filename to match: BcelClassWeaver.java
# GT norm: weaver5/java5-src/org/aspectj/weaver/reflect/JavaLangTypeToResolvedTypeConverter.java
# Filename to match: JavaLangTypeToResolvedTypeConverter.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelShadow.java
# Filename to match: BcelShadow.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/ClassLoaderWeavingAdaptor.java
# Filename to match: ClassLoaderWeavingAdaptor.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/LazyClassGen.java
# Filename to match: LazyClassGen.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWeaver.java
# Filename to match: BcelWeaver.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/World.java
# Filename to match: World.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/Utility.java
# Filename to match: Utility.java
# GT norm: tests/multiIncremental/PR278496_10/base/com/Asp.java
# Filename to match: Asp.java
# GT norm: tests/multiIncremental/PR278496_10/base/com/Foo.java
# Filename to match: Foo.java
# GT norm: tests/multiIncremental/PR278496_11/base/com/Foo.java
# Filename to match: Foo.java
# GT norm: tests/multiIncremental/PR278496_11_a/base/com/Asp.java
# Filename to match: Asp.java
# GT norm: tests/multiIncremental/PR278496_11_a/base/com/Dibble.java
# Filename to match: Dibble.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/AtAjAttributes.java
# Filename to match: AtAjAttributes.java
# GT norm: tests/bugs1612/pr327134/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/ajc1612/Ajc1612Tests.java
# Filename to match: Ajc1612Tests.java
# GT norm: tests/bugs1612/pr339974/City.java
# Filename to match: City.java
# GT norm: tests/bugs1612/pr339974/TrafficCalculator.java
# Filename to match: TrafficCalculator.java
# GT norm: tests/bugs1612/pr342605/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/ajc1612/Ajc1612Tests.java
# Filename to match: Ajc1612Tests.java
# GT norm: org.aspectj.matcher/testdata/AnnotatedClass.java
# Filename to match: AnnotatedClass.java
# GT norm: org.aspectj.matcher/testdata/MethodLevelAnnotation.java
# Filename to match: MethodLevelAnnotation.java
# GT norm: org.aspectj.matcher/testdata/SomeAnnotation.java
# Filename to match: SomeAnnotation.java
# GT norm: org.aspectj.matcher/testsrc/org/aspectj/matcher/tools/CommonAdvancedPointcutExpressionTests.java
# Filename to match: CommonAdvancedPointcutExpressionTests.java
# GT norm: org.aspectj.matcher/testsrc/testdata/AnnotatedClass.java
# Filename to match: AnnotatedClass.java
# GT norm: org.aspectj.matcher/testsrc/testdata/MethodLevelAnnotation.java
# Filename to match: MethodLevelAnnotation.java
# GT norm: org.aspectj.matcher/testsrc/testdata/SomeAnnotation.java
# Filename to match: SomeAnnotation.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelTypeMunger.java
# Filename to match: BcelTypeMunger.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelObjectType.java
# Filename to match: BcelObjectType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/TypeVariable.java
# Filename to match: TypeVariable.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/TypeVariableReferenceType.java
# Filename to match: TypeVariableReferenceType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/World.java
# Filename to match: World.java
# GT norm: util/src/org/aspectj/util/FileUtil.java
# Filename to match: FileUtil.java
# GT norm: asm/src/org/aspectj/asm/internal/AspectJElementHierarchy.java
# Filename to match: AspectJElementHierarchy.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/reflect/ShadowMatchImpl.java
# Filename to match: ShadowMatchImpl.java
# GT norm: org.aspectj.matcher/testsrc/org/aspectj/weaver/patterns/ThisOrTargetTestCase.java
# Filename to match: ThisOrTargetTestCase.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjState.java
# Filename to match: AjState.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/ModifiersPattern.java
# Filename to match: ModifiersPattern.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ReferenceType.java
# Filename to match: ReferenceType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/World.java
# Filename to match: World.java
# GT norm: tests/multiIncremental/pr322039/base/src/p/Azpect.java
# Filename to match: Azpect.java
# GT norm: tests/multiIncremental/pr322039/base/src/q2/Code.java
# Filename to match: Code.java
# GT norm: tests/src/org/aspectj/systemtest/incremental/tools/MultiProjectIncrementalTests.java
# Filename to match: MultiProjectIncrementalTests.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/AjLookupEnvironment.java
# Filename to match: AjLookupEnvironment.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/ClassLoaderWeavingAdaptor.java
# Filename to match: ClassLoaderWeavingAdaptor.java
# GT norm: loadtime/testsrc/org/aspectj/weaver/loadtime/ClassLoaderWeavingAdaptorTest.java
# Filename to match: ClassLoaderWeavingAdaptorTest.java
# GT norm: loadtime/testsrc/testdata/MessageService$$EnhancerByCGLIB$$6dd4e683.java
# Filename to match: MessageService$$EnhancerByCGLIB$$6dd4e683.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseSourceType.java
# Filename to match: EclipseSourceType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/BindingScope.java
# Filename to match: BindingScope.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/IScope.java
# Filename to match: IScope.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/SimpleScope.java
# Filename to match: SimpleScope.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/WildTypePattern.java
# Filename to match: WildTypePattern.java
# GT norm: org.aspectj.matcher/testsrc/org/aspectj/weaver/patterns/PatternsTests.java
# Filename to match: PatternsTests.java
# GT norm: org.aspectj.matcher/testsrc/org/aspectj/weaver/patterns/SimpleScopeTests.java
# Filename to match: SimpleScopeTests.java
# GT norm: org.aspectj.matcher/testsrc/org/aspectj/weaver/patterns/TypePatternTestCase.java
# Filename to match: TypePatternTestCase.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelObjectType.java
# Filename to match: BcelObjectType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/Advice.java
# Filename to match: Advice.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelObjectType.java
# Filename to match: BcelObjectType.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWorld.java
# Filename to match: BcelWorld.java
# GT norm: weaver/src/org/aspectj/weaver/tools/WeavingAdaptor.java
# Filename to match: WeavingAdaptor.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/patterns/PointcutEvaluationExpenseComparator.java
# Filename to match: PointcutEvaluationExpenseComparator.java
# GT norm: org.aspectj.matcher/testsrc/org/aspectj/weaver/patterns/PointcutRewriterTest.java
# Filename to match: PointcutRewriterTest.java
# GT norm: weaver/src/org/aspectj/weaver/model/AsmRelationshipProvider.java
# Filename to match: AsmRelationshipProvider.java
# GT norm: asm/src/org/aspectj/asm/AsmManager.java
# Filename to match: AsmManager.java
# GT norm: asm/src/org/aspectj/asm/internal/ProgramElement.java
# Filename to match: ProgramElement.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/tools/ajc/Main.java
# Filename to match: Main.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseResolvedMember.java
# Filename to match: EclipseResolvedMember.java
# GT norm: tests/bugs169/pr291206/One.java
# Filename to match: One.java
# GT norm: tests/bugs169/pr291206/Three.java
# Filename to match: Three.java
# GT norm: tests/bugs169/pr291206/Two.java
# Filename to match: Two.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/AjLookupEnvironment.java
# Filename to match: AjLookupEnvironment.java
# GT norm: asm/src/org/aspectj/asm/internal/AspectJElementHierarchy.java
# Filename to match: AspectJElementHierarchy.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/ClassLoaderWeavingAdaptor.java
# Filename to match: ClassLoaderWeavingAdaptor.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/AjAttribute.java
# Filename to match: AjAttribute.java
# GT norm: loadtime5/java5-src/org/aspectj/weaver/loadtime/ClassPreProcessorAgentAdapter.java
# Filename to match: ClassPreProcessorAgentAdapter.java
# GT norm: tests/bugs167/pr293457/org/springmodules/cache/annotations/Cacheable.java
# Filename to match: Cacheable.java
# GT norm: tests/src/org/aspectj/systemtest/ajc167/Ajc167Tests.java
# Filename to match: Ajc167Tests.java
# GT norm: tests/src/org/aspectj/systemtest/ajc167/IntertypeTests.java
# Filename to match: IntertypeTests.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/MissingResolvedTypeWithKnownSignature.java
# Filename to match: MissingResolvedTypeWithKnownSignature.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/AtAjAttributes.java
# Filename to match: AtAjAttributes.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/ExtensibleURLClassLoader.java
# Filename to match: ExtensibleURLClassLoader.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWorld.java
# Filename to match: BcelWorld.java
# GT norm: util/src/org/aspectj/util/LangUtil.java
# Filename to match: LangUtil.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/Lint.java
# Filename to match: Lint.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelObjectType.java
# Filename to match: BcelObjectType.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/World.java
# Filename to match: World.java
# GT norm: ajdoc/src/org/aspectj/tools/ajdoc/JavadocRunner.java
# Filename to match: JavadocRunner.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelObjectType.java
# Filename to match: BcelObjectType.java
# GT norm: weaver/src/org/aspectj/weaver/loadtime/definition/DocumentParser.java
# Filename to match: DocumentParser.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/InterTypeMethodDeclaration.java
# Filename to match: InterTypeMethodDeclaration.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: asm/src/org/aspectj/asm/internal/JDTLikeHandleProvider.java
# Filename to match: JDTLikeHandleProvider.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjState.java
# Filename to match: AjState.java
# GT norm: weaver/src/org/aspectj/weaver/model/AsmRelationshipProvider.java
# Filename to match: AsmRelationshipProvider.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/EclipseAdapterUtils.java
# Filename to match: EclipseAdapterUtils.java
# GT norm: aspectj5rt/java5-src/org/aspectj/lang/reflect/AjTypeSystem.java
# Filename to match: AjTypeSystem.java
# GT norm: asm/src/org/aspectj/asm/internal/AspectJElementHierarchy.java
# Filename to match: AspectJElementHierarchy.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjState.java
# Filename to match: AjState.java
# GT norm: asm/src/org/aspectj/asm/internal/AspectJElementHierarchy.java
# Filename to match: AspectJElementHierarchy.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelTypeMunger.java
# Filename to match: BcelTypeMunger.java
# GT norm: org.aspectj.matcher/src/org/aspectj/weaver/ShadowMunger.java
# Filename to match: ShadowMunger.java
# GT norm: asm/src/org/aspectj/asm/internal/JDTLikeHandleProvider.java
# Filename to match: JDTLikeHandleProvider.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelClassWeaver.java
# Filename to match: BcelClassWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelTypeMunger.java
# Filename to match: BcelTypeMunger.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWeaver.java
# Filename to match: BcelWeaver.java
# GT norm: taskdefs/src/org/aspectj/tools/ant/taskdefs/AjcTask.java
# Filename to match: AjcTask.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/ajc/ConfigParser.java
# Filename to match: ConfigParser.java
# GT norm: tests/multiIncremental/pr259528/base/src/b/IsAdvised.java
# Filename to match: IsAdvised.java
# GT norm: tests/multiIncremental/pr259528/inc1/src/b/IsAdvised.java
# Filename to match: IsAdvised.java
# GT norm: tests/bugs163/pr251326/pkgA/Listener.java
# Filename to match: Listener.java
# GT norm: tests/bugs163/pr251326/pkgA/Target.java
# Filename to match: Target.java
# GT norm: tests/src/org/aspectj/systemtest/ajc163/Ajc163Tests.java
# Filename to match: Ajc163Tests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/AtAjAttributes.java
# Filename to match: AtAjAttributes.java
# GT norm: weaver/src/org/aspectj/weaver/model/AsmRelationshipProvider.java
# Filename to match: AsmRelationshipProvider.java
# GT norm: asm/src/org/aspectj/asm/internal/JDTLikeHandleProvider.java
# Filename to match: JDTLikeHandleProvider.java
# GT norm: tests/bugs163/pr249710/Foo.java
# Filename to match: Foo.java
# GT norm: tests/src/org/aspectj/systemtest/ajc163/Ajc163Tests.java
# Filename to match: Ajc163Tests.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelShadow.java
# Filename to match: BcelShadow.java
# GT norm: tests/multiIncremental/PR192877/base/src/DefaultTestImpl.java
# Filename to match: DefaultTestImpl.java
# GT norm: tests/multiIncremental/PR192877/base/src/Foo.java
# Filename to match: Foo.java
# GT norm: tests/multiIncremental/PR192877/base/src/FooImpl.java
# Filename to match: FooImpl.java
# GT norm: tests/multiIncremental/PR192877/base/src/Test.java
# Filename to match: Test.java
# GT norm: tests/multiIncremental/PR192877/base/src/TestAspect.java
# Filename to match: TestAspect.java
# GT norm: tests/multiIncremental/PR192877/inc1/src/Test.java
# Filename to match: Test.java
# GT norm: tests/src/org/aspectj/systemtest/incremental/tools/MultiProjectIncrementalTests.java
# Filename to match: MultiProjectIncrementalTests.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseResolvedMember.java
# Filename to match: EclipseResolvedMember.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelShadow.java
# Filename to match: BcelShadow.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildConfig.java
# Filename to match: AjBuildConfig.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: docs/dist/doc/examples/introduction/Point.java
# Filename to match: Point.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/ClassLoaderWeavingAdaptor.java
# Filename to match: ClassLoaderWeavingAdaptor.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseSourceType.java
# Filename to match: EclipseSourceType.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/AndAnnotationTypePattern.java
# Filename to match: AndAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/NotAnnotationTypePattern.java
# Filename to match: NotAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/OrAnnotationTypePattern.java
# Filename to match: OrAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WildAnnotationTypePattern.java
# Filename to match: WildAnnotationTypePattern.java
# GT norm: tests/bugs161/pr203367/CantMatchOnInterfaceIntroducedToGenericClass.java
# Filename to match: CantMatchOnInterfaceIntroducedToGenericClass.java
# GT norm: tests/src/org/aspectj/systemtest/ajc161/Ajc161Tests.java
# Filename to match: Ajc161Tests.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/IfPointcut.java
# Filename to match: IfPointcut.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseFactory.java
# Filename to match: EclipseFactory.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWeaver.java
# Filename to match: BcelWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelClassWeaver.java
# Filename to match: BcelClassWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/TypeFactory.java
# Filename to match: TypeFactory.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/EclipseAdapterUtils.java
# Filename to match: EclipseAdapterUtils.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelClassWeaver.java
# Filename to match: BcelClassWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/LazyMethodGen.java
# Filename to match: LazyMethodGen.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/org/eclipse/jdt/core/dom/AjASTMatcher.java
# Filename to match: AjASTMatcher.java
# GT norm: taskdefs/src/org/aspectj/tools/ant/taskdefs/AjcTask.java
# Filename to match: AjcTask.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/AjLookupEnvironment.java
# Filename to match: AjLookupEnvironment.java
# GT norm: weaver/src/org/aspectj/weaver/ResolvedType.java
# Filename to match: ResolvedType.java
# GT norm: weaver5/java5-src/org/aspectj/weaver/reflect/Java15AnnotationFinder.java
# Filename to match: Java15AnnotationFinder.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWeaver.java
# Filename to match: BcelWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/World.java
# Filename to match: World.java
# GT norm: weaver5/java5-src/org/aspectj/weaver/reflect/Java15ReflectionBasedReferenceTypeDelegate.java
# Filename to match: Java15ReflectionBasedReferenceTypeDelegate.java
# GT norm: weaver5/java5-src/org/aspectj/weaver/reflect/Java15AnnotationFinder.java
# Filename to match: Java15AnnotationFinder.java
# GT norm: weaver/src/org/aspectj/weaver/Shadow.java
# Filename to match: Shadow.java
# GT norm: runtime/src/org/aspectj/lang/ProceedingJoinPoint.java
# Filename to match: ProceedingJoinPoint.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/org/eclipse/jdt/core/dom/AjASTConverter.java
# Filename to match: AjASTConverter.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/org/eclipse/jdt/core/dom/InterTypeFieldDeclaration.java
# Filename to match: InterTypeFieldDeclaration.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/org/eclipse/jdt/core/dom/InterTypeMethodDeclaration.java
# Filename to match: InterTypeMethodDeclaration.java
# GT norm: tests/bugs154/pr211674/Test.java
# Filename to match: Test.java
# GT norm: tests/bugs154/pr211674/Test2.java
# Filename to match: Test2.java
# GT norm: tests/src/org/aspectj/systemtest/ajc154/Ajc154Tests.java
# Filename to match: Ajc154Tests.java
# GT norm: weaver/src/org/aspectj/weaver/ResolvedType.java
# Filename to match: ResolvedType.java
# GT norm: weaver/src/org/aspectj/weaver/TypeFactory.java
# Filename to match: TypeFactory.java
# GT norm: weaver/testsrc/org/aspectj/weaver/TypeXTestCase.java
# Filename to match: TypeXTestCase.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/problem/AjProblemReporter.java
# Filename to match: AjProblemReporter.java
# GT norm: taskdefs/src/org/aspectj/tools/ant/taskdefs/AjcTask.java
# Filename to match: AjcTask.java
# GT norm: loadtime/src/org/aspectj/weaver/loadtime/ConcreteAspectCodeGen.java
# Filename to match: ConcreteAspectCodeGen.java
# GT norm: ajde/src/org/aspectj/ajde/BuildOptionsAdapter.java
# Filename to match: BuildOptionsAdapter.java
# GT norm: ajde/src/org/aspectj/ajde/internal/CompilerAdapter.java
# Filename to match: CompilerAdapter.java
# GT norm: ajde/testsrc/org/aspectj/ajde/BuildConfigurationTests.java
# Filename to match: BuildConfigurationTests.java
# GT norm: tests/bugs153/pr161502/Main.java
# Filename to match: Main.java
# GT norm: tests/bugs153/pr161502/Main2.java
# Filename to match: Main2.java
# GT norm: tests/src/org/aspectj/systemtest/ajc153/Ajc153Tests.java
# Filename to match: Ajc153Tests.java
# GT norm: weaver/src/org/aspectj/weaver/BoundedReferenceType.java
# Filename to match: BoundedReferenceType.java
# GT norm: weaver/src/org/aspectj/weaver/Checker.java
# Filename to match: Checker.java
# GT norm: weaver/src/org/aspectj/weaver/ReferenceType.java
# Filename to match: ReferenceType.java
# GT norm: weaver/src/org/aspectj/weaver/ResolvedPointcutDefinition.java
# Filename to match: ResolvedPointcutDefinition.java
# GT norm: weaver/src/org/aspectj/weaver/ResolvedType.java
# Filename to match: ResolvedType.java
# GT norm: weaver/src/org/aspectj/weaver/TypeVariable.java
# Filename to match: TypeVariable.java
# GT norm: weaver/src/org/aspectj/weaver/TypeVariableReferenceType.java
# Filename to match: TypeVariableReferenceType.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelAdvice.java
# Filename to match: BcelAdvice.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelTypeMunger.java
# Filename to match: BcelTypeMunger.java
# GT norm: weaver/src/org/aspectj/weaver/internal/tools/PointcutDesignatorHandlerBasedPointcut.java
# Filename to match: PointcutDesignatorHandlerBasedPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/AndAnnotationTypePattern.java
# Filename to match: AndAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/AndPointcut.java
# Filename to match: AndPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/AndTypePattern.java
# Filename to match: AndTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/AnnotationPatternList.java
# Filename to match: AnnotationPatternList.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/AnnotationPointcut.java
# Filename to match: AnnotationPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/AnnotationTypePattern.java
# Filename to match: AnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ArgsAnnotationPointcut.java
# Filename to match: ArgsAnnotationPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ArgsPointcut.java
# Filename to match: ArgsPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/BindingAnnotationTypePattern.java
# Filename to match: BindingAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/BindingTypePattern.java
# Filename to match: BindingTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/CflowPointcut.java
# Filename to match: CflowPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ConcreteCflowPointcut.java
# Filename to match: ConcreteCflowPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/Declare.java
# Filename to match: Declare.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/DeclareAnnotation.java
# Filename to match: DeclareAnnotation.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/DeclareErrorOrWarning.java
# Filename to match: DeclareErrorOrWarning.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/DeclareParents.java
# Filename to match: DeclareParents.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/DeclarePrecedence.java
# Filename to match: DeclarePrecedence.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/DeclareSoft.java
# Filename to match: DeclareSoft.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ExactAnnotationTypePattern.java
# Filename to match: ExactAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ExactTypePattern.java
# Filename to match: ExactTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/HandlerPointcut.java
# Filename to match: HandlerPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/HasMemberTypePattern.java
# Filename to match: HasMemberTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/IfPointcut.java
# Filename to match: IfPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/KindedPointcut.java
# Filename to match: KindedPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/NotAnnotationTypePattern.java
# Filename to match: NotAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/NotPointcut.java
# Filename to match: NotPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/NotTypePattern.java
# Filename to match: NotTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/OrAnnotationTypePattern.java
# Filename to match: OrAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/OrPointcut.java
# Filename to match: OrPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/OrTypePattern.java
# Filename to match: OrTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/PerCflow.java
# Filename to match: PerCflow.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/PerFromSuper.java
# Filename to match: PerFromSuper.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/PerObject.java
# Filename to match: PerObject.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/PerSingleton.java
# Filename to match: PerSingleton.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/PerTypeWithin.java
# Filename to match: PerTypeWithin.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/Pointcut.java
# Filename to match: Pointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ReferencePointcut.java
# Filename to match: ReferencePointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/SignaturePattern.java
# Filename to match: SignaturePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ThisOrTargetAnnotationPointcut.java
# Filename to match: ThisOrTargetAnnotationPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ThisOrTargetPointcut.java
# Filename to match: ThisOrTargetPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/ThrowsPattern.java
# Filename to match: ThrowsPattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/TypePattern.java
# Filename to match: TypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/TypePatternList.java
# Filename to match: TypePatternList.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WildAnnotationTypePattern.java
# Filename to match: WildAnnotationTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WildTypePattern.java
# Filename to match: WildTypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WithinAnnotationPointcut.java
# Filename to match: WithinAnnotationPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WithinCodeAnnotationPointcut.java
# Filename to match: WithinCodeAnnotationPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WithinPointcut.java
# Filename to match: WithinPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WithincodePointcut.java
# Filename to match: WithincodePointcut.java
# GT norm: tests/bugs153/pr149908/C.java
# Filename to match: C.java
# GT norm: tests/bugs153/pr149908/C1.java
# Filename to match: C1.java
# GT norm: tests/bugs153/pr149908/MyStringBuilder.java
# Filename to match: MyStringBuilder.java
# GT norm: tests/bugs153/pr149908/withoutMethod/MyStringBuilder.java
# Filename to match: MyStringBuilder.java
# GT norm: tests/src/org/aspectj/systemtest/ajc153/Ajc153Tests.java
# Filename to match: Ajc153Tests.java
# GT norm: weaver/src/org/aspectj/weaver/MemberImpl.java
# Filename to match: MemberImpl.java
# GT norm: ajdoc/src/org/aspectj/tools/ajdoc/Main.java
# Filename to match: Main.java
# ...
# Filename to match: AjdtBuilderTests.java
# GT norm: org.aspectj.ajdt.core/testsrc/org/aspectj/ajdt/internal/core/builder/AsmBuilderTest.java
# Filename to match: AsmBuilderTest.java
# GT norm: tests/bugs/bootstrapClasspath/UsesDOMParser.java
# Filename to match: UsesDOMParser.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AsmBuilder.java
# Filename to match: AsmBuilder.java
# GT norm: taskdefs/src/org/aspectj/tools/ant/taskdefs/AjcTask.java
# Filename to match: AjcTask.java
# GT norm: taskdefs/src/org/aspectj/tools/ant/taskdefs/ICommandEditor.java
# Filename to match: ICommandEditor.java
# GT norm: taskdefs/testsrc/org/aspectj/tools/ant/taskdefs/AjcTaskTest.java
# Filename to match: AjcTaskTest.java
# GT norm: ajbrowser/src/org/aspectj/tools/ajbrowser/BasicEditor.java
# Filename to match: BasicEditor.java
# GT norm: ajbrowser/src/org/aspectj/tools/ajbrowser/BrowserManager.java
# Filename to match: BrowserManager.java
# GT norm: ajbrowser/src/org/aspectj/tools/ajbrowser/BuildConfigPopupMenu.java
# Filename to match: BuildConfigPopupMenu.java
# GT norm: ajbrowser/src/org/aspectj/tools/ajbrowser/CompilerMessagesPanel.java
# Filename to match: CompilerMessagesPanel.java
# GT norm: ajbrowser/src/org/aspectj/tools/ajbrowser/EditorManager.java
# Filename to match: EditorManager.java
# GT norm: ajbrowser/src/org/aspectj/tools/ajbrowser/TopFrame.java
# Filename to match: TopFrame.java
# GT norm: ajde/src/org/aspectj/ajde/Ajde.java
# Filename to match: Ajde.java
# GT norm: ajde/src/org/aspectj/ajde/ui/EditorManager.java
# Filename to match: EditorManager.java
# GT norm: ajde/src/org/aspectj/ajde/ui/StructureModelUtil.java
# Filename to match: StructureModelUtil.java
# GT norm: ajde/src/org/aspectj/ajde/ui/StructureViewManager.java
# Filename to match: StructureViewManager.java
# GT norm: ajde/src/org/aspectj/ajde/ui/swing/AjdeUIManager.java
# Filename to match: AjdeUIManager.java
# GT norm: ajde/src/org/aspectj/ajde/ui/swing/BasicEditor.java
# Filename to match: BasicEditor.java
# GT norm: ajde/src/org/aspectj/ajde/ui/swing/BrowserViewManager.java
# Filename to match: BrowserViewManager.java
# GT norm: ajde/src/org/aspectj/ajde/ui/swing/BrowserViewTreeListener.java
# Filename to match: BrowserViewTreeListener.java
# GT norm: ajde/src/org/aspectj/ajde/ui/swing/BuildConfigPopupMenu.java
# Filename to match: BuildConfigPopupMenu.java
# GT norm: ajde/src/org/aspectj/ajde/ui/swing/PointcutWizard.java
# Filename to match: PointcutWizard.java
# GT norm: ajde/src/org/aspectj/ajde/ui/swing/StructureViewPanel.java
# Filename to match: StructureViewPanel.java
# GT norm: ajde/testsrc/AjdeModuleTests.java
# Filename to match: AjdeModuleTests.java
# GT norm: ajde/testsrc/org/aspectj/ajde/CompilerMessagesTest.java
# Filename to match: CompilerMessagesTest.java
# GT norm: ajde/testsrc/org/aspectj/ajde/NullIdeEditorAdapter.java
# Filename to match: NullIdeEditorAdapter.java
# GT norm: ajde/testsrc/org/aspectj/ajde/NullIdeManager.java
# Filename to match: NullIdeManager.java
# GT norm: ajde/src/org/aspectj/ajde/internal/CompilerAdapter.java
# Filename to match: CompilerAdapter.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/ajc/AjdtCommand.java
# Filename to match: AjdtCommand.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/ajc/BuildArgParser.java
# Filename to match: BuildArgParser.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/InterSuperFixerVisitor.java
# Filename to match: InterSuperFixerVisitor.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/InterSuperReference.java
# Filename to match: InterSuperReference.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/InterTypeDeclaration.java
# Filename to match: InterTypeDeclaration.java
# GT norm: tests/bugs/MultipleSuperCf.java
# Filename to match: MultipleSuperCf.java
# GT norm: tests/bugs/OverridingInterfaceObjectMethod.java
# Filename to match: OverridingInterfaceObjectMethod.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelTypeMunger.java
# Filename to match: BcelTypeMunger.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/AccessForInlineVisitor.java
# Filename to match: AccessForInlineVisitor.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/AdviceDeclaration.java
# Filename to match: AdviceDeclaration.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/PrivilegedHandler.java
# Filename to match: PrivilegedHandler.java
# GT norm: tests/bugs/MissingImport.java
# Filename to match: MissingImport.java
# GT norm: tests/bugs/NewVoid.java
# Filename to match: NewVoid.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: org.aspectj.ajdt.core/testdata/src1/WrongPackage.java
# Filename to match: WrongPackage.java
# GT norm: org.aspectj.ajdt.core/testsrc/org/aspectj/ajdt/internal/compiler/batch/BasicCommandTestCase.java
# Filename to match: BasicCommandTestCase.java
# GT norm: tests/bugs/CatchSig.java
# Filename to match: CatchSig.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelShadow.java
# Filename to match: BcelShadow.java
# GT norm: tests/new/binaryWarnings/src/app/Main.java
# Filename to match: Main.java
# GT norm: tests/new/binaryWarnings/src/aspects/MainWarnings.java
# Filename to match: MainWarnings.java
# GT norm: tests/bugs/BadBindingError.java
# Filename to match: BadBindingError.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelClassWeaver.java
# Filename to match: BcelClassWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/TypePattern.java
# Filename to match: TypePattern.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WildTypePattern.java
# Filename to match: WildTypePattern.java
# GT norm: tests/bugs/interSpecials/Asp.java
# Filename to match: Asp.java
# GT norm: tests/bugs/interSpecials/Trg.java
# Filename to match: Trg.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildManager.java
# Filename to match: AjBuildManager.java
# GT norm: org.aspectj.ajdt.core/testsrc/org/aspectj/ajdt/internal/compiler/batch/BasicCommandTestCase.java
# Filename to match: BasicCommandTestCase.java
# GT norm: tests/bugs/CflowConcrete.java
# Filename to match: CflowConcrete.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/KindedPointcut.java
# Filename to match: KindedPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/Pointcut.java
# Filename to match: Pointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WithinPointcut.java
# Filename to match: WithinPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WithincodePointcut.java
# Filename to match: WithincodePointcut.java
# GT norm: tests/bugs/StackError.java
# Filename to match: StackError.java
# GT norm: tests/bugs/messyAround/cap/OptionList.java
# Filename to match: OptionList.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelShadow.java
# Filename to match: BcelShadow.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/LazyMethodGen.java
# Filename to match: LazyMethodGen.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/ThisJoinPointVisitor.java
# Filename to match: ThisJoinPointVisitor.java
# GT norm: tests/bugs/tjpStaticPart/Exceptions.java
# Filename to match: Exceptions.java
# GT norm: tests/bugs/tjpStaticPart/Test.java
# Filename to match: Test.java
# GT norm: tests/bugs/interInherit/a_impl/AImpl.java
# Filename to match: AImpl.java
# GT norm: tests/bugs/interInherit/a_impl/Af.java
# Filename to match: Af.java
# GT norm: tests/bugs/interInherit/a_intf/A.java
# Filename to match: A.java
# GT norm: tests/bugs/interInherit/b_impl/BImpl.java
# Filename to match: BImpl.java
# GT norm: tests/bugs/interInherit/b_intf/B.java
# Filename to match: B.java
# GT norm: tests/bugs/interAbstract/Driver.java
# Filename to match: Driver.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelClassWeaver.java
# Filename to match: BcelClassWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/LazyClassGen.java
# Filename to match: LazyClassGen.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/LazyMethodGen.java
# Filename to match: LazyMethodGen.java
# GT norm: ajde/testdata/examples/declare-warning/apackage/InitCatcher.java
# Filename to match: InitCatcher.java
# GT norm: ajde/testdata/examples/declare-warning/apackage/SomeClass.java
# Filename to match: SomeClass.java
# GT norm: ajde/testsrc/org/aspectj/ajde/AjdeTestCase.java
# Filename to match: AjdeTestCase.java
# GT norm: ajde/testsrc/org/aspectj/ajde/AjdeTests.java
# Filename to match: AjdeTests.java
# GT norm: ajde/testsrc/org/aspectj/ajde/CompilerMessagesTest.java
# Filename to match: CompilerMessagesTest.java
# GT norm: ajde/testsrc/org/aspectj/ajde/NullIdeManager.java
# Filename to match: NullIdeManager.java
# GT norm: ajde/testsrc/org/aspectj/ajde/NullIdeTaskListManager.java
# Filename to match: NullIdeTaskListManager.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseShadow.java
# Filename to match: EclipseShadow.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/problem/AjProblemReporter.java
# Filename to match: AjProblemReporter.java
# GT norm: tests/bugs/ConvertToUnchecked.java
# Filename to match: ConvertToUnchecked.java
# GT norm: tests/bugs/CflowBinding.java
# Filename to match: CflowBinding.java
# GT norm: tests/bugs/CflowBindingOrig.java
# Filename to match: CflowBindingOrig.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/CflowPointcut.java
# Filename to match: CflowPointcut.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseAdvice.java
# Filename to match: EclipseAdvice.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseFactory.java
# Filename to match: EclipseFactory.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelShadow.java
# Filename to match: BcelShadow.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelRenderer.java
# Filename to match: BcelRenderer.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/Utility.java
# Filename to match: Utility.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/EclipseScope.java
# Filename to match: EclipseScope.java
# GT norm: tests/bugs/InnerPointcut.java
# Filename to match: InnerPointcut.java
# GT norm: tests/bugs/interfaceNames/TransactionTest.java
# Filename to match: TransactionTest.java
# GT norm: tests/bugs/interfaceNames/sub/ExecutionMonitor.java
# Filename to match: ExecutionMonitor.java
# GT norm: tests/new/EachObjectInDeepPackage.java
# Filename to match: EachObjectInDeepPackage.java
# GT norm: tests/bugs/ConstructorDeclaration.java
# Filename to match: ConstructorDeclaration.java
# GT norm: tests/bugs/WeaveLocal.java
# Filename to match: WeaveLocal.java
# GT norm: weaver/src/org/aspectj/weaver/NameMangler.java
# Filename to match: NameMangler.java
# GT norm: weaver/src/org/aspectj/weaver/ResolvedTypeX.java
# Filename to match: ResolvedTypeX.java
# GT norm: weaver/src/org/aspectj/weaver/TypeX.java
# Filename to match: TypeX.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/WithinPointcut.java
# Filename to match: WithinPointcut.java
# GT norm: weaver/testsrc/org/aspectj/weaver/TypeXTestCase.java
# Filename to match: TypeXTestCase.java
# GT norm: tests/bugs/NotIf.java
# Filename to match: NotIf.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/IfPointcut.java
# Filename to match: IfPointcut.java
# GT norm: tests/bugs/Finalizer.java
# Filename to match: Finalizer.java
# GT norm: tests/bugs/AdviceExec.java
# Filename to match: AdviceExec.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/KindedPointcut.java
# Filename to match: KindedPointcut.java
# GT norm: weaver/src/org/aspectj/weaver/patterns/SignaturePattern.java
# Filename to match: SignaturePattern.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/ThisJoinPointVisitor.java
# Filename to match: ThisJoinPointVisitor.java
# GT norm: tests/bugs/crashes/test/Test3.java
# Filename to match: Test3.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/InterTypeConstructorDeclaration.java
# Filename to match: InterTypeConstructorDeclaration.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/ast/SuperFixerVisitor.java
# Filename to match: SuperFixerVisitor.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/compiler/lookup/InterTypeMethodBinding.java
# Filename to match: InterTypeMethodBinding.java
# GT norm: org.eclipse.jdt.core/compiler/org/eclipse/jdt/internal/compiler/ast/AllocationExpression.java
# Filename to match: AllocationExpression.java
# GT norm: org.eclipse.jdt.core/compiler/org/eclipse/jdt/internal/compiler/ast/ExplicitConstructorCall.java
# Filename to match: ExplicitConstructorCall.java
# GT norm: org.eclipse.jdt.core/compiler/org/eclipse/jdt/internal/compiler/ast/MessageSend.java
# Filename to match: MessageSend.java
# GT norm: org.eclipse.jdt.core/compiler/org/eclipse/jdt/internal/compiler/lookup/MethodBinding.java
# Filename to match: MethodBinding.java
# GT norm: tests/bugs/SuperToIntro.java
# Filename to match: SuperToIntro.java
# GT norm: ajbrowser/src/org/aspectj/tools/ajbrowser/BrowserProperties.java
# Filename to match: BrowserProperties.java
# GT norm: ajde/src/org/aspectj/ajde/BuildOptionsAdapter.java
# Filename to match: BuildOptionsAdapter.java
# GT norm: ajde/src/org/aspectj/ajde/ProjectPropertiesAdapter.java
# Filename to match: ProjectPropertiesAdapter.java
# GT norm: ajde/src/org/aspectj/ajde/internal/AspectJBuildManager.java
# Filename to match: AspectJBuildManager.java
# GT norm: ajde/src/org/aspectj/ajde/internal/CompilerAdapter.java
# Filename to match: CompilerAdapter.java
# GT norm: ajde/src/org/aspectj/ajde/ui/internal/AjcBuildOptions.java
# Filename to match: AjcBuildOptions.java
# GT norm: ajde/testdata/examples/figures-coverage/figures/Figure.java
# Filename to match: Figure.java
# GT norm: ajde/testsrc/org/aspectj/ajde/AjdeTests.java
# Filename to match: AjdeTests.java
# GT norm: ajde/testsrc/org/aspectj/ajde/BuildConfigurationTests.java
# Filename to match: BuildConfigurationTests.java
# GT norm: ajde/testsrc/org/aspectj/ajde/BuildOptionsTest.java
# Filename to match: BuildOptionsTest.java
# GT norm: ajde/testsrc/org/aspectj/ajde/NullIdeManager.java
# Filename to match: NullIdeManager.java
# GT norm: ajde/testsrc/org/aspectj/ajde/NullIdeProperties.java
# Filename to match: NullIdeProperties.java
# GT norm: ajde/testsrc/org/aspectj/ajde/StructureModelRegressionTest.java
# Filename to match: StructureModelRegressionTest.java
# GT norm: ajde/testsrc/org/aspectj/ajde/StructureModelTest.java
# Filename to match: StructureModelTest.java
# GT norm: ajde/testsrc/org/aspectj/ajde/ui/StructureViewManagerTest.java
# Filename to match: StructureViewManagerTest.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/ajc/BuildArgParser.java
# Filename to match: BuildArgParser.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AjBuildConfig.java
# Filename to match: AjBuildConfig.java
# GT norm: org.aspectj.ajdt.core/testsrc/org/aspectj/ajdt/ajc/BuildArgParserTestCase.java
# Filename to match: BuildArgParserTestCase.java
# GT norm: tests/bugs/AroundAccess.java
# Filename to match: AroundAccess.java
# GT norm: asm/src/org/aspectj/asm/StructureModel.java
# Filename to match: StructureModel.java
# GT norm: org.aspectj.ajdt.core/src/org/aspectj/ajdt/internal/core/builder/AsmBuilder.java
# Filename to match: AsmBuilder.java
# GT norm: weaver/src/org/aspectj/weaver/AsmAdaptor.java
# Filename to match: AsmAdaptor.java
# GT norm: weaver/src/org/aspectj/weaver/Lint.java
# Filename to match: Lint.java
# GT norm: weaver/src/org/aspectj/weaver/ResolvedTypeX.java
# Filename to match: ResolvedTypeX.java
# GT norm: weaver/src/org/aspectj/weaver/Shadow.java
# Filename to match: Shadow.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/BcelWeaver.java
# Filename to match: BcelWeaver.java
# GT norm: weaver/src/org/aspectj/weaver/bcel/LazyMethodGen.java
# Filename to match: LazyMethodGen.java
# GT norm: weaver/src/org/aspectj/weaver/AjcMemberMaker.java
# Filename to match: AjcMemberMaker.java
#     BugID  Rank
# 0  423257     5
# 1  420210     1
# 2  419279     3
# 3  415266    67
# 4  418129     3

# %%
TOP_N = 10   # change to required value

rows_for_csv = []

# Normalize file paths first
normalized_paths = [p.replace("\\", "/") for p in file_paths]

for _, row in bugs_df.iterrows():
    bug_id = row["bug_id"]

    # sorted ranked list of source files (high → low similarity)
    ranks_dict = bug_rankings[bug_id]

    # Sort by rank (1 is best)
    sorted_files = sorted(ranks_dict.items(), key=lambda x: x[1])

    # Take top-N file paths
    top_n_files = [path for path, rank in sorted_files[:TOP_N]]

    # Prepare row dict
    entry = {"BugID": bug_id}

    for i, f in enumerate(top_n_files, start=1):
        entry[f"File{i}"] = f

    rows_for_csv.append(entry)

# Make DataFrame + Save
output_df = pd.DataFrame(rows_for_csv)
output_df.to_csv("bug_localization_topN.csv", index=False)

output_df.head()
# Out:
#     BugID                                              File1  \
# 0  423257  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  420210  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  419279  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  415266  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  418129  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                                File2  \
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                                File3  \
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                                File4  \
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                                File5  \
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                                File6  \
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                                File7  \
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                                File8  \
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                                File9  \
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...
#
#                                               File10
# 0  CIS580_Assignment_BugLocalization\sourceFile_a...
# 1  CIS580_Assignment_BugLocalization\sourceFile_a...
# 2  CIS580_Assignment_BugLocalization\sourceFile_a...
# 3  CIS580_Assignment_BugLocalization\sourceFile_a...
# 4  CIS580_Assignment_BugLocalization\sourceFile_a...

# %%
(result_df["Rank"] == 1).sum()
# Out:
# np.int64(170)

# %%
result_df["Rank"].describe()
# Out:
# count     593.000000
# mean       95.227656
# std       243.581214
# min         1.000000
# 25%         1.000000
# 50%         9.000000
# 75%        63.000000
# max      1801.000000
# Name: Rank, dtype: float64
